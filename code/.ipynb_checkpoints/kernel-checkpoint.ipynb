# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import KFold
import warnings
import time
import sys
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
sample = pd.read_csv('../input/new_merchant_transactions.csv',nrows=10)
dtypes = sample.dtypes

col_types = {}
remap = {np.int64: np.int16, np.float64:np.float16}
for column,typ in dtypes.items():
    col_types[column] = remap.get(typ.type,typ.type)

col_types
# Out:
# {'authorized_flag': numpy.object_,
#  'card_id': numpy.object_,
#  'city_id': numpy.int16,
#  'category_1': numpy.object_,
#  'installments': numpy.int16,
#  'category_3': numpy.object_,
#  'merchant_category_id': numpy.int16,
#  'merchant_id': numpy.object_,
#  'month_lag': numpy.int16,
#  'purchase_amount': numpy.float16,
#  'purchase_date': numpy.object_,
#  'category_2': numpy.float16,
#  'state_id': numpy.int16,
#  'subsector_id': numpy.int16}

# %%
new_transactions = pd.read_csv('../input/new_merchant_transactions.csv', parse_dates=['purchase_date'],dtype=col_types)
historical_transactions = pd.read_csv('../input/historical_transactions.csv', parse_dates=['purchase_date'],dtype=col_types)

def binarize(df):
    for col in ['authorized_flag', 'category_1']:
        df[col] = df[col].map({'Y':1, 'N':0}).astype(np.int8)
    return df

historical_transactions = binarize(historical_transactions)
new_transactions = binarize(new_transactions)

# %%
historical_transactions.memory_usage()
# Out:
# Index                          80
# authorized_flag          29112361
# card_id                 232898888
# city_id                  58224722
# category_1               29112361
# installments             58224722
# category_3              232898888
# merchant_category_id     58224722
# merchant_id             232898888
# month_lag                58224722
# purchase_amount          58224722
# purchase_date           232898888
# category_2               58224722
# state_id                 58224722
# subsector_id             58224722
# dtype: int64

# %%
new_transactions.memory_usage()
# Out:
# Index                         80
# authorized_flag          1963031
# card_id                 15704248
# city_id                  3926062
# category_1               1963031
# installments             3926062
# category_3              15704248
# merchant_category_id     3926062
# merchant_id             15704248
# month_lag                3926062
# purchase_amount          3926062
# purchase_date           15704248
# category_2               3926062
# state_id                 3926062
# subsector_id             3926062
# dtype: int64

# %%
def read_data(input_file):
    df = pd.read_csv(input_file)
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['elapsed_time'] = (datetime.date(2018, 2, 1) - df['first_active_month'].dt.date).dt.days
    return df
#_________________________________________
train = read_data('../input/train.csv')
test = read_data('../input/test.csv')

target = train['target']
del train['target']

# %%
historical_transactions = pd.get_dummies(historical_transactions, columns=['category_2', 'category_3'])
new_transactions = pd.get_dummies(new_transactions, columns=['category_2', 'category_3'])

historical_transactions = reduce_mem_usage(historical_transactions)
new_transactions = reduce_mem_usage(new_transactions)

agg_fun = {'authorized_flag': ['sum', 'mean']}
auth_mean = historical_transactions.groupby(['card_id']).agg(agg_fun)
auth_mean.columns = ['_'.join(col).strip() for col in auth_mean.columns.values]
auth_mean.reset_index(inplace=True)

authorized_transactions = historical_transactions[historical_transactions['authorized_flag'] == 1]
historical_transactions = historical_transactions[historical_transactions['authorized_flag'] == 0]
# Out:
# Mem. usage decreased to 1415.95 Mb (-6.2% reduction)
# Mem. usage decreased to 84.24 Mb (6.2% reduction)

# %%
historical_transactions[:5]
# Out:
#      authorized_flag          card_id      ...       category_3_B  category_3_C
# 115                0  C_ID_4e6213e9bc      ...                  0             0
# 132                0  C_ID_4e6213e9bc      ...                  0             0
# 148                0  C_ID_4e6213e9bc      ...                  0             0
# 168                0  C_ID_4e6213e9bc      ...                  0             0
# 213                0  C_ID_4e6213e9bc      ...                  0             0
#
# [5 rows x 20 columns]

# %%
historical_transactions['purchase_month'] = historical_transactions['purchase_date'].dt.month
authorized_transactions['purchase_month'] = authorized_transactions['purchase_date'].dt.month
new_transactions['purchase_month'] = new_transactions['purchase_date'].dt.month

# %%
def aggregate_transactions(history):
    
    history.loc[:, 'purchase_date'] = pd.DatetimeIndex(history['purchase_date']).\
                                      astype(np.int64) * 1e-9
    
    agg_func = {
        'category_1': ['sum', 'mean'],
        'category_2_1.0': ['mean'],
        'category_2_2.0': ['mean'],
        'category_2_3.0': ['mean'],
        'category_2_4.0': ['mean'],
        'category_2_5.0': ['mean'],
        'category_3_A': ['mean'],
        'category_3_B': ['mean'],
        'category_3_C': ['mean'],
        'merchant_id': ['nunique'],
        'merchant_category_id': ['nunique'],
        'state_id': ['nunique'],
        'city_id': ['nunique'],
        'subsector_id': ['nunique'],
        'purchase_amount': ['sum', 'mean', 'max', 'min', 'std'],
        'installments': ['sum', 'mean', 'max', 'min', 'std'],
        'purchase_month': ['mean', 'max', 'min', 'std'],
        'purchase_date': [np.ptp],
        'month_lag': ['min', 'max']
        }
    
    agg_history = history.groupby(['card_id']).agg(agg_func)
    agg_history.columns = ['_'.join(col).strip() for col in agg_history.columns.values]
    agg_history.reset_index(inplace=True)
    
    df = (history.groupby('card_id')
          .size()
          .reset_index(name='transactions_count'))
    
    agg_history = pd.merge(df, agg_history, on='card_id', how='left')
    
    return agg_history

# %%
history = aggregate_transactions(historical_transactions)
history.columns = ['hist_' + c if c != 'card_id' else c for c in history.columns]
history[:5]
# Out:
#            card_id         ...          hist_month_lag_max
# 0  C_ID_00007093c1         ...                           0
# 1  C_ID_0001238066         ...                           0
# 2  C_ID_0001506ef0         ...                           0
# 3  C_ID_0001793786         ...                          -1
# 4  C_ID_000183fdda         ...                          -4
#
# [5 rows x 34 columns]

# %%
authorized = aggregate_transactions(authorized_transactions)
authorized.columns = ['auth_' + c if c != 'card_id' else c for c in authorized.columns]
authorized[:5]
# Out:
#            card_id         ...          auth_month_lag_max
# 0  C_ID_00007093c1         ...                           0
# 1  C_ID_0001238066         ...                           0
# 2  C_ID_0001506ef0         ...                           0
# 3  C_ID_0001793786         ...                           0
# 4  C_ID_000183fdda         ...                           0
#
# [5 rows x 34 columns]

# %%
new = aggregate_transactions(new_transactions)
new.columns = ['new_' + c if c != 'card_id' else c for c in new.columns]
new[:5]
# Out:
#            card_id        ...          new_month_lag_max
# 0  C_ID_00007093c1        ...                          2
# 1  C_ID_0001238066        ...                          2
# 2  C_ID_0001506ef0        ...                          1
# 3  C_ID_0001793786        ...                          2
# 4  C_ID_000183fdda        ...                          2
#
# [5 rows x 34 columns]

# %%
def aggregate_per_month(history):
    grouped = history.groupby(['card_id', 'month_lag'])

    agg_func = {
            'purchase_amount': ['count', 'sum', 'mean', 'min', 'max', 'std'],
            'installments': ['count', 'sum', 'mean', 'min', 'max', 'std'],
            }

    intermediate_group = grouped.agg(agg_func)
    intermediate_group.columns = ['_'.join(col).strip() for col in intermediate_group.columns.values]
    intermediate_group.reset_index(inplace=True)

    final_group = intermediate_group.groupby('card_id').agg(['mean', 'std'])
    final_group.columns = ['_'.join(col).strip() for col in final_group.columns.values]
    final_group.reset_index(inplace=True)
    
    return final_group
#___________________________________________________________
final_group =  aggregate_per_month(historical_transactions) 
final_group[:10]
# Out:
#            card_id          ...           installments_std_std
# 0  C_ID_00007093c1          ...                       0.480551
# 1  C_ID_0001238066          ...                            NaN
# 2  C_ID_0001506ef0          ...                            NaN
# 3  C_ID_0001793786          ...                       0.279244
# 4  C_ID_000183fdda          ...                            NaN
# 5  C_ID_00024e244b          ...                       0.312603
# 6  C_ID_0002709b5a          ...                            NaN
# 7  C_ID_00027503e2          ...                       0.000000
# 8  C_ID_000298032a          ...                            NaN
# 9  C_ID_0002ba3c2e          ...                       0.000000
#
# [10 rows x 27 columns]

# %%
train = pd.merge(train, history, on='card_id', how='left')
test = pd.merge(test, history, on='card_id', how='left')

train = pd.merge(train, authorized, on='card_id', how='left')
test = pd.merge(test, authorized, on='card_id', how='left')

train = pd.merge(train, new, on='card_id', how='left')
test = pd.merge(test, new, on='card_id', how='left')

train = pd.merge(train, final_group, on='card_id', how='left')
test = pd.merge(test, final_group, on='card_id', how='left')

train = pd.merge(train, auth_mean, on='card_id', how='left')
test = pd.merge(test, auth_mean, on='card_id', how='left')

# %%
features = [c for c in train.columns if c not in ['card_id', 'first_active_month']]
categorical_feats = [c for c in features if 'feature_' in c]

# %%
param = {'num_leaves': 100,
         'min_data_in_leaf': 30, 
         'objective':'regression',
         'max_depth': 6,
         'learning_rate': 0.005,
         "min_child_samples": 20,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "bagging_seed": 11,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "verbosity": -1}
folds = KFold(n_splits=5, shuffle=True, random_state=15)
oof = np.zeros(len(train))
predictions = np.zeros(len(test))
start = time.time()
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, target.values)):
    print("fold n°{}".format(fold_))
    trn_data = lgb.Dataset(train.iloc[trn_idx][features], label=target.iloc[trn_idx], categorical_feature=categorical_feats)
    val_data = lgb.Dataset(train.iloc[val_idx][features], label=target.iloc[val_idx], categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 200)
    oof[val_idx] = clf.predict(train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(mean_squared_error(oof, target)**0.5))
# Out:
# fold n°0
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1186: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:752: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.74971	valid_1's rmse: 3.80901
# [200]	training's rmse: 3.6953	valid_1's rmse: 3.77116
# [300]	training's rmse: 3.65667	valid_1's rmse: 3.74751
# [400]	training's rmse: 3.62876	valid_1's rmse: 3.73175
# [500]	training's rmse: 3.60679	valid_1's rmse: 3.71998
# [600]	training's rmse: 3.58934	valid_1's rmse: 3.71269
# [700]	training's rmse: 3.57579	valid_1's rmse: 3.70788
# [800]	training's rmse: 3.56425	valid_1's rmse: 3.70441
# [900]	training's rmse: 3.55378	valid_1's rmse: 3.70166
# [1000]	training's rmse: 3.54414	valid_1's rmse: 3.6994
# [1100]	training's rmse: 3.53516	valid_1's rmse: 3.69766
# [1200]	training's rmse: 3.52621	valid_1's rmse: 3.6964
# [1300]	training's rmse: 3.51787	valid_1's rmse: 3.69521
# [1400]	training's rmse: 3.51	valid_1's rmse: 3.69442
# [1500]	training's rmse: 3.50246	valid_1's rmse: 3.69379
# [1600]	training's rmse: 3.49495	valid_1's rmse: 3.69365
# [1700]	training's rmse: 3.48733	valid_1's rmse: 3.69298
# [1800]	training's rmse: 3.47991	valid_1's rmse: 3.69269
# [1900]	training's rmse: 3.4728	valid_1's rmse: 3.69234
# [2000]	training's rmse: 3.4663	valid_1's rmse: 3.69228
# [2100]	training's rmse: 3.45927	valid_1's rmse: 3.69207
# [2200]	training's rmse: 3.45286	valid_1's rmse: 3.69213
# [2300]	training's rmse: 3.44668	valid_1's rmse: 3.69183
# [2400]	training's rmse: 3.44041	valid_1's rmse: 3.6919
# [2500]	training's rmse: 3.43436	valid_1's rmse: 3.69185
# [2600]	training's rmse: 3.4286	valid_1's rmse: 3.69168
# [2700]	training's rmse: 3.42286	valid_1's rmse: 3.69166
# [2800]	training's rmse: 3.41652	valid_1's rmse: 3.69153
# [2900]	training's rmse: 3.41057	valid_1's rmse: 3.69147
# [3000]	training's rmse: 3.40428	valid_1's rmse: 3.69149
# [3100]	training's rmse: 3.39841	valid_1's rmse: 3.69175
# Early stopping, best iteration is:
# [2906]	training's rmse: 3.41024	valid_1's rmse: 3.69143
# fold n°1
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1186: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:752: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.76486	valid_1's rmse: 3.7386
# [200]	training's rmse: 3.70859	valid_1's rmse: 3.7075
# [300]	training's rmse: 3.67006	valid_1's rmse: 3.68841
# [400]	training's rmse: 3.64172	valid_1's rmse: 3.67515
# [500]	training's rmse: 3.61912	valid_1's rmse: 3.66628
# [600]	training's rmse: 3.60101	valid_1's rmse: 3.66005
# [700]	training's rmse: 3.58645	valid_1's rmse: 3.65606
# [800]	training's rmse: 3.57361	valid_1's rmse: 3.65306
# [900]	training's rmse: 3.5627	valid_1's rmse: 3.6508
# [1000]	training's rmse: 3.55266	valid_1's rmse: 3.64906
# [1100]	training's rmse: 3.5438	valid_1's rmse: 3.64784
# [1200]	training's rmse: 3.53488	valid_1's rmse: 3.64681
# [1300]	training's rmse: 3.52669	valid_1's rmse: 3.64606
# [1400]	training's rmse: 3.51887	valid_1's rmse: 3.64535
# [1500]	training's rmse: 3.51093	valid_1's rmse: 3.64497
# [1600]	training's rmse: 3.50369	valid_1's rmse: 3.64467
# [1700]	training's rmse: 3.49654	valid_1's rmse: 3.64445
# [1800]	training's rmse: 3.489	valid_1's rmse: 3.64385
# [1900]	training's rmse: 3.48166	valid_1's rmse: 3.64317
# [2000]	training's rmse: 3.47484	valid_1's rmse: 3.64291
# [2100]	training's rmse: 3.46808	valid_1's rmse: 3.6427
# [2200]	training's rmse: 3.46156	valid_1's rmse: 3.64278
# Early stopping, best iteration is:
# [2078]	training's rmse: 3.46989	valid_1's rmse: 3.64261
# fold n°2
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1186: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:752: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.77285	valid_1's rmse: 3.70976
# [200]	training's rmse: 3.71698	valid_1's rmse: 3.67736
# [300]	training's rmse: 3.67521	valid_1's rmse: 3.65662
# [400]	training's rmse: 3.64523	valid_1's rmse: 3.64303
# [500]	training's rmse: 3.62254	valid_1's rmse: 3.634
# [600]	training's rmse: 3.60496	valid_1's rmse: 3.62847
# [700]	training's rmse: 3.59039	valid_1's rmse: 3.6253
# [800]	training's rmse: 3.57884	valid_1's rmse: 3.62309
# [900]	training's rmse: 3.56864	valid_1's rmse: 3.62138
# [1000]	training's rmse: 3.55908	valid_1's rmse: 3.62016
# [1100]	training's rmse: 3.55039	valid_1's rmse: 3.61942
# [1200]	training's rmse: 3.54114	valid_1's rmse: 3.61879
# [1300]	training's rmse: 3.53256	valid_1's rmse: 3.61849
# [1400]	training's rmse: 3.52455	valid_1's rmse: 3.61813
# [1500]	training's rmse: 3.51657	valid_1's rmse: 3.61796
# [1600]	training's rmse: 3.50931	valid_1's rmse: 3.6181
# [1700]	training's rmse: 3.50178	valid_1's rmse: 3.6182
# Early stopping, best iteration is:
# [1572]	training's rmse: 3.51137	valid_1's rmse: 3.61782
# fold n°3
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1186: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:752: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.72326	valid_1's rmse: 3.91129
# [200]	training's rmse: 3.66826	valid_1's rmse: 3.87477
# [300]	training's rmse: 3.62931	valid_1's rmse: 3.8526
# [400]	training's rmse: 3.59967	valid_1's rmse: 3.83827
# [500]	training's rmse: 3.57716	valid_1's rmse: 3.82924
# [600]	training's rmse: 3.55851	valid_1's rmse: 3.82313
# [700]	training's rmse: 3.54386	valid_1's rmse: 3.8195
# [800]	training's rmse: 3.53166	valid_1's rmse: 3.81682
# [900]	training's rmse: 3.52133	valid_1's rmse: 3.81506
# [1000]	training's rmse: 3.51296	valid_1's rmse: 3.81371
# [1100]	training's rmse: 3.5044	valid_1's rmse: 3.81268
# [1200]	training's rmse: 3.49634	valid_1's rmse: 3.812
# [1300]	training's rmse: 3.48851	valid_1's rmse: 3.81128
# [1400]	training's rmse: 3.48085	valid_1's rmse: 3.81059
# [1500]	training's rmse: 3.47286	valid_1's rmse: 3.81004
# [1600]	training's rmse: 3.46597	valid_1's rmse: 3.80959
# [1700]	training's rmse: 3.45884	valid_1's rmse: 3.80898
# [1800]	training's rmse: 3.45159	valid_1's rmse: 3.80867
# [1900]	training's rmse: 3.44449	valid_1's rmse: 3.80821
# [2000]	training's rmse: 3.43786	valid_1's rmse: 3.80804
# [2100]	training's rmse: 3.43105	valid_1's rmse: 3.80768
# [2200]	training's rmse: 3.42428	valid_1's rmse: 3.80754
# [2300]	training's rmse: 3.41801	valid_1's rmse: 3.80766
# Early stopping, best iteration is:
# [2193]	training's rmse: 3.42476	valid_1's rmse: 3.80751
# fold n°4
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1186: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:752: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.76717	valid_1's rmse: 3.72953
# [200]	training's rmse: 3.70995	valid_1's rmse: 3.69899
# [300]	training's rmse: 3.67112	valid_1's rmse: 3.68019
# [400]	training's rmse: 3.64021	valid_1's rmse: 3.66503
# [500]	training's rmse: 3.61725	valid_1's rmse: 3.65587
# [600]	training's rmse: 3.59907	valid_1's rmse: 3.64995
# [700]	training's rmse: 3.58405	valid_1's rmse: 3.6459
# [800]	training's rmse: 3.57137	valid_1's rmse: 3.64319
# [900]	training's rmse: 3.55901	valid_1's rmse: 3.64153
# [1000]	training's rmse: 3.54897	valid_1's rmse: 3.64044
# [1100]	training's rmse: 3.53988	valid_1's rmse: 3.63982
# [1200]	training's rmse: 3.53185	valid_1's rmse: 3.63925
# [1300]	training's rmse: 3.5239	valid_1's rmse: 3.63889
# [1400]	training's rmse: 3.51631	valid_1's rmse: 3.6384
# [1500]	training's rmse: 3.50901	valid_1's rmse: 3.63814
# [1600]	training's rmse: 3.5013	valid_1's rmse: 3.63795
# [1700]	training's rmse: 3.49365	valid_1's rmse: 3.63781
# [1800]	training's rmse: 3.48674	valid_1's rmse: 3.63781
# [1900]	training's rmse: 3.47965	valid_1's rmse: 3.63786
# [2000]	training's rmse: 3.47249	valid_1's rmse: 3.63786
# Early stopping, best iteration is:
# [1813]	training's rmse: 3.48579	valid_1's rmse: 3.63775
# CV score: 3.68006

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
sub_df = pd.DataFrame({"card_id":test["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv("submit.csv", index=False)
